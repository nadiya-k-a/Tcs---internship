# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiya-k-a/Tcs---internship/blob/main/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dataframe prepration

# %%
##importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##test data set from kaggle
df = pd.read_csv('/content/drive/MyDrive/drugsComTest_raw.csv')

# %%
##trian data set from kaggle
df1 = pd.read_csv('/content/drive/MyDrive/drugsComTrain_raw.csv')

# %%
df.head()
# Out:
#    uniqueID         drugName                     condition  \
# 0    163740      Mirtazapine                    Depression
# 1    206473       Mesalamine  Crohn's Disease, Maintenance
# 2    159672          Bactrim       Urinary Tract Infection
# 3     39293         Contrave                   Weight Loss
# 4     97768  Cyclafem 1 / 35                 Birth Control
#
#                                               review  rating       date  \
# 0  "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# 1  "My son has Crohn&#039;s disease and has done ...       8  17-May-09
# 2                      "Quick reduction of symptoms"       9  29-Sep-17
# 3  "Contrave combines drugs that were used for al...       9   5-Mar-17
# 4  "I have been on this birth control for one cyc...       9  22-Oct-15
#
#    usefulCount
# 0           22
# 1           17
# 2            3
# 3           35
# 4            4

# %%
##joining test and train dataset
df = pd.concat([df,df1])

# %%
##dropping the review column
df.drop('review',axis = 1,inplace = True)

# %%
##shape of new dataset
df.shape
# Out:
# (215063, 6)

# %%
##dropping duplicate values
new_df = df.drop_duplicates()

# %%
# !pip install Faker
import faker
# Out:
# Collecting Faker
#   Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: Faker
# Successfully installed Faker-19.13.0

# %%
from faker import Faker

fake = Faker()

np.random.seed(123)
random.seed(123) # setting seed for faker library

# %%
new_df.shape
# Out:
# (215063, 6)

# %%
new_df.head()
# Out:
#    uniqueID         drugName                     condition  rating       date  \
# 0    163740      Mirtazapine                    Depression      10  28-Feb-12
# 1    206473       Mesalamine  Crohn's Disease, Maintenance       8  17-May-09
# 2    159672          Bactrim       Urinary Tract Infection       9  29-Sep-17
# 3     39293         Contrave                   Weight Loss       9   5-Mar-17
# 4     97768  Cyclafem 1 / 35                 Birth Control       9  22-Oct-15
#
#    usefulCount
# 0           22
# 1           17
# 2            3
# 3           35
# 4            4

# %%
##no of rows needed to  add make it 400000
new_rows = 400000 - df.shape[0]
new_data = []

# %%
## Adding new rows to reach 400,000 rows
# Set a random seed
np.random.seed(123)
for _ in range(new_rows):
    random_entry = df.sample()
    new_entry = random_entry.copy()


    new_entry['uniqueID'] += 1
    new_entry['rating'] = np.random.randint(1, 10)
    new_entry['usefulCount'] = np.random.randint(1, 50)

    new_data.append(new_entry)

new_df = pd.concat([df] + new_data, ignore_index=True)

print(f"New dataframe shape: {new_df.shape}")
print(new_df.head())
# Out:
# New dataframe shape: (400000, 6)
#    uniqueID         drugName                     condition  rating       date  \
# 0    163740      Mirtazapine                    Depression      10  28-Feb-12
# 1    206473       Mesalamine  Crohn's Disease, Maintenance       8  17-May-09
# 2    159672          Bactrim       Urinary Tract Infection       9  29-Sep-17
# 3     39293         Contrave                   Weight Loss       9   5-Mar-17
# 4     97768  Cyclafem 1 / 35                 Birth Control       9  22-Oct-15
#
#    usefulCount
# 0           22
# 1           17
# 2            3
# 3           35
# 4            4

# %%
new_df.shape
# Out:
# (400000, 6)

# %%
new_df.drop_duplicates(inplace = True)

# %%
new_df.shape
# Out:
# (399819, 6)

# %%
new_df.shape
# Out:
# (399819, 6)

# %%
new_df.tail()
# Out:
#         uniqueID            drugName                condition  rating  \
# 399995    139970            Euflexxa           Osteoarthritis       1
# 399996    151195           OxyContin                     Pain       7
# 399997     26115            Sprintec            Birth Control       4
# 399998    170693          Quetiapine               Depression       8
# 399999    105753  Methylprednisolone  Inflammatory Conditions       2
#
#              date  usefulCount
# 399995  14-Jul-10           12
# 399996   7-Jan-10           16
# 399997  17-Jan-17           42
# 399998  20-Nov-13           39
# 399999  19-Oct-13           40

# %% [markdown]
# ### Adding Age column to the dataset

# %%
np.random.seed(123)

ages = np.random.randint(low=18, high=81, size=len(new_df))
age = pd.DataFrame({'Age': ages})

# %% [markdown]
# ### Creating Name column using faker library

# %%
np.random.seed(123)
fake_names = []
for _ in range(len(new_df)):
    fake_names.append(fake.name())

# %%
names = pd.DataFrame({'Name': fake_names})

# %% [markdown]
# ### Side effects column

# %%
np.random.seed(123)
# Define the side effects
# Define the side effects
side_effects = ['Moderate Side Effects', 'Severe Side Effects', 'Extremely Severe Side Effects',
                'Mild Side Effects', 'No Side Effects']

# Define the desired distribution of side effects (weights)
weights = [0.22, 0.28, 0.13, 0.2, 0.17]  # Example weights, adjust as needed

# Generate imbalanced side effects column
side_effects_column =np.random.choice(side_effects,size = len(new_df) ,p=weights)

# %%
side_effect= pd.DataFrame({'Side effects': side_effects_column})

# %% [markdown]
# ### Race column

# %%
np.random.seed(123)
# Define the races
races = ["Asian", "African", "White", "Hispanic", "Mixed"]
weights = [0.28, 0.15, 0.12, 0.25, 0.2]
race_column = np.random.choice(races,size = len(new_df) ,p=weights)

# %%
race= pd.DataFrame({'Race': race_column})

# %% [markdown]
# ### Gender column

# %%
np.random.seed(123)
# Generate fake gender data
# Generate fake gender data
weights = [0.3, 0.7]
genders = random.choices(['Male', 'Female'], weights=weights, k=len(new_df))

gender = pd.DataFrame({'Gender': genders})

# %%
df_new = pd.concat([gender,race,side_effect,names,age],axis=1)

# %%
df_new.shape
# Out:
# (399819, 5)

# %%
new_df.shape
# Out:
# (399819, 6)

# %%
df_new.head()
# Out:
#    Gender      Race                   Side effects            Name  Age
# 0    Male  Hispanic              Mild Side Effects     Glenn Smith   80
# 1    Male   African            Severe Side Effects   Gregory Lopez   63
# 2  Female     Asian            Severe Side Effects    Alicia Weiss   80
# 3    Male  Hispanic  Extremely Severe Side Effects     Aaron Smith   20
# 4  Female  Hispanic              Mild Side Effects  Jenna Morrison   46

# %%
df_new = df_new.reset_index(drop=True)
new_df = new_df.reset_index(drop=True)

# %%
data = pd.concat([new_df,df_new],axis=1)

# %%
data.shape
# Out:
# (399819, 11)

# %%
data.drop_duplicates(inplace =True)

# %%
data.columns
# Out:
# Index(['uniqueID', 'drugName', 'condition', 'rating', 'date', 'usefulCount',
#        'Gender', 'Race', 'Side effects', 'Name', 'Age'],
#       dtype='object')

# %%
column_order = ['uniqueID','Name', 'Gender','Age','Race','drugName','condition','rating', 'date','usefulCount','Side effects']

# %%
data = data[column_order]

# %%
data.isna().sum()
# Out:
# uniqueID           0
# Name               0
# Gender             0
# Age                0
# Race               0
# drugName           0
# condition       2298
# rating             0
# date               0
# usefulCount        0
# Side effects       0
# dtype: int64

# %%
# Descriptive status of numerical columns
data.describe().T
# Out:
#                 count           mean           std   min      25%       50%  \
# uniqueID     399819.0  116037.183553  66968.215158   0.0  58167.0  115909.0
# Age          399819.0      48.972563     18.181783  18.0     33.0      49.0
# rating       399819.0       6.073458      3.135697   1.0      3.0       7.0
# usefulCount  399819.0      26.602805     28.373669   0.0      8.0      21.0
#
#                   75%       max
# uniqueID     173852.5  232291.0
# Age              65.0      80.0
# rating            9.0      10.0
# usefulCount      37.0    1291.0

# %%
# Descriptive status of categorical columns
data.describe(include = 'object').T
# Out:
#                count  unique                  top    freq
# Name          399819  192698        Michael Smith     210
# Gender        399819       2               Female  279932
# Race          399819       5                Asian  112149
# drugName      399819    3671       Levonorgestrel    9187
# condition     397521     916        Birth Control   71639
# date          399819    3579            27-Jan-16     368
# Side effects  399819       5  Severe Side Effects  111882

# %%
# Checking for misssing values
data.isna().sum()
# Out:
# uniqueID           0
# Name               0
# Gender             0
# Age                0
# Race               0
# drugName           0
# condition       2298
# rating             0
# date               0
# usefulCount        0
# Side effects       0
# dtype: int64

# %%
##converting dataframe into csv file

data.to_csv('data2.csv', index=False)

# %%
data = pd.read_csv('/content/data2.csv')

# %%
data.head()
# Out:
#    uniqueID            Name  Gender  Age      Race         drugName  \
# 0    163740     Glenn Smith    Male   80  Hispanic      Mirtazapine
# 1    206473   Gregory Lopez    Male   63   African       Mesalamine
# 2    159672    Alicia Weiss  Female   80     Asian          Bactrim
# 3     39293     Aaron Smith    Male   20  Hispanic         Contrave
# 4     97768  Jenna Morrison  Female   46  Hispanic  Cyclafem 1 / 35
#
#                       condition  rating       date  usefulCount  \
# 0                    Depression      10  28-Feb-12           22
# 1  Crohn's Disease, Maintenance       8  17-May-09           17
# 2       Urinary Tract Infection       9  29-Sep-17            3
# 3                   Weight Loss       9   5-Mar-17           35
# 4                 Birth Control       9  22-Oct-15            4
#
#                     Side effects
# 0              Mild Side Effects
# 1            Severe Side Effects
# 2            Severe Side Effects
# 3  Extremely Severe Side Effects
# 4              Mild Side Effects

# %%
data[data['condition'].isnull()]
# Out:
#         uniqueID             Name  Gender  Age      Race  \
# 34         77164    Rita Stephens  Female   20   African
# 146       192374  Gary Hutchinson  Female   19  Hispanic
# 156       165767        Vickie Li  Female   77  Hispanic
# 779       157589  Joshua Lawrence  Female   50     Mixed
# 1017       96918     David Barnes  Female   65     White
# ...          ...              ...     ...  ...       ...
# 399197    195259   Drew Gomez DDS    Male   71  Hispanic
# 399304    104876      Kevin Lewis  Female   56     Mixed
# 399328    200096   Dennis Swanson  Female   35  Hispanic
# 399594    206487      Jacob Adams  Female   38     Asian
# 399625     93840    Connor Turner  Female   45     Mixed
#
#                                           drugName condition  rating  \
# 34                                      Lorcaserin       NaN       5
# 146               Drospirenone / ethinyl estradiol       NaN       4
# 156                                 Levonorgestrel       NaN       7
# 779                                    Guaifenesin       NaN       9
# 1017    Conjugated estrogens / medroxyprogesterone       NaN       1
# ...                                            ...       ...     ...
# 399197                    Dutasteride / tamsulosin       NaN       6
# 399304          Ethinyl estradiol / levonorgestrel       NaN       3
# 399328                                 Varenicline       NaN       9
# 399594                                  Mesalamine       NaN       4
# 399625                                    Morphine       NaN       8
#
#              date  usefulCount           Side effects
# 34      27-May-14           21    Severe Side Effects
# 146     13-Apr-15            8      Mild Side Effects
# 156      3-Apr-17            0      Mild Side Effects
# 779     23-Feb-10           10        No Side Effects
# 1017     6-Jul-15            5    Severe Side Effects
# ...           ...          ...                    ...
# 399197   1-Mar-13           18      Mild Side Effects
# 399304  27-Jan-10           43        No Side Effects
# 399328  31-Aug-15            8      Mild Side Effects
# 399594   8-Oct-08           34  Moderate Side Effects
# 399625  20-Jun-08           11        No Side Effects
#
# [2298 rows x 11 columns]
